# %%
def librerias():
    
    '''Empezamos importando las librerìas necesarias para el desarrollo del algoritmo '''
    
import pandas as pd
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.tree import export_graphviz
from six import StringIO 
from IPython.display import Image  
import pydotplus
from sklearn.metrics import confusion_matrix
import seaborn as sn
import matplotlib.pyplot as plt

print(librerias.__doc__)
# Out:
# Empezamos importando las librerìas necesarias para el desarrollo del algoritmo

# %%
def importarData():
   
    ''' Creamos la funciòn para importar nuestro Dataset, el cual se trata de conocer si una persona padece Diabetes o no! '''
    
pima= pd.read_csv('Dataset_Diabetes.csv')

print(importarData.__doc__)

pima.head()
# Out:
#  Creamos la funciòn para importar nuestro Dataset, el cual se trata de conocer si una persona padece Diabetes o no!
#     ID  No_Pation Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221      M   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656      F   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223      M   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
#
#     BMI CLASS
# 0  24.0     N
# 1  23.0     N
# 2  24.0     N
# 3  24.0     N
# 4  21.0     N

# %%
def DelectEsp():
    
    ''' Creamos una función utilizando el método Strip, el cual nos permite eliminar espacios en blancos encontrados dentro de la colunma CLASS '''

pima['CLASS']= pima['CLASS'].str.strip()

print(DelectEsp.__doc__)
# Out:
#  Creamos una función utilizando el método Strip, el cual nos permite eliminar espacios en blancos encontrados dentro de la colunma CLASS

# %%
def TransDatos():
    
     ''' Realizamos una función mediante el uso del método map para transformar los datos de las columnas Gender y Class a datos categóricos '''

transf1 = {'F':0, 'M':1, 'f':0}
pima['Gender'] =pima['Gender'].map(transf1)
transf2 = {'N':0,'P':1,'Y':2}
pima['CLASS'] =pima['CLASS'].map(transf2)

print(TransDatos.__doc__)
# Out:
#  Realizamos una función mediante el uso del método map para transformar los datos de las columnas Gender y Class a datos categóricos

# %%
def importarData():

    ''' Se realiza una función mediante el uso del método head,el cual nos imprime los primeros datos del Dataset '''

print(importarData.__doc__)

pima.head(10)
# Out:
#  Se realiza una función mediante el uso del método head,el cual nos imprime los primeros datos del Dataset
#     ID  No_Pation  Gender  AGE  Urea  Cr  HbA1c  Chol   TG  HDL  LDL  VLDL  \
# 0  502      17975       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 1  735      34221       1   26   4.5  62    4.9   3.7  1.4  1.1  2.1   0.6
# 2  420      47975       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 3  680      87656       0   50   4.7  46    4.9   4.2  0.9  2.4  1.4   0.5
# 4  504      34223       1   33   7.1  46    4.9   4.9  1.0  0.8  2.0   0.4
# 5  634      34224       0   45   2.3  24    4.0   2.9  1.0  1.0  1.5   0.4
# 6  721      34225       0   50   2.0  50    4.0   3.6  1.3  0.9  2.1   0.6
# 7  421      34227       1   48   4.7  47    4.0   2.9  0.8  0.9  1.6   0.4
# 8  670      34229       1   43   2.6  67    4.0   3.8  0.9  2.4  3.7   1.0
# 9  759      34230       0   32   3.6  28    4.0   3.8  2.0  2.4  3.8   1.0
#
#     BMI  CLASS
# 0  24.0      0
# ...

# %%
def defCarac():
    

    ''' Creamos la funciòn que nos permite separar los datos de nuestra Dataset, en este caso escogemos las caracteristicas (X) la cuales nos serviran para realizar nuestra predicciòn'''

caracteristicas = ['No_Pation', 'Gender', 'AGE', 'Urea', 'Cr', 'HbA1c', 'Chol', 'TG', 'HDL', 'LDL', 'VLDL', 'BMI']

X = pima[caracteristicas]
    
    
print(defCarac.__doc__)
# Out:
#  Creamos la funciòn que nos permite separar los datos de nuestra Dataset, en este caso escogemos las caracteristicas (X) la cuales nos serviran para realizar nuestra predicciòn

# %%
def defEtiq():

    ''' Seguidamente escogemos la etiqueta la cual nos permitirà predecir un valor'''
    
y = pima.CLASS

print(defEtiq.__doc__)
# Out:
#  Seguidamente escogemos la etiqueta la cual nos permitirà predecir un valor

# %%
def crearFunc():
    
    ''' Creamos la funciòn para poder entrenar el modelo, se toma el 70% de datos para entrenar y el 30% de datos se toma para realizar las pruebas al azar '''

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=1)
    
print(crearFunc.__doc__)
# Out:
#  Creamos la funciòn para poder entrenar el modelo, se toma el 70% de datos para entrenar y el 30% de datos se toma para realizar las pruebas al azar

# %%
def funcArb():
    
    ''' Como primer paso se crea el àrbol de decisiòn y se entrena el modelo para que revele la predicciòn de los datos de prueba'''

clf = DecisionTreeClassifier()
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
    
print(funcArb.__doc__)
# Out:
#  Como primer paso se crea el àrbol de decisiòn y se entrena el modelo para que revele la predicciòn de los datos de prueba

# %%
def mostArbol():

    ''' Creamos la funciòn donde se crea un objeto el cual recibe un búfer de cadenas, seguido a esto se exporta el árbol en formato DOT para crear nuestro gráfico y así guarda la imagen en formato png '''

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,
                feature_names = caracteristicas,
                class_names=['0','1','2'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('diabetes.png')

print(mostArbol.__doc__)
Image(graph.create_png())
# Out:
#  Creamos la funciòn donde se crea un objeto el cual recibe un búfer de cadenas, seguido a esto se exporta el árbol en formato DOT para crear nuestro gráfico y así guarda la imagen en formato png

# %%
def metAccu():
    
    ''' Se procede a evaluar el modelo entrenado mediante las metricas empezamos evaluando el Accuray'''

print("Accuracy:", metrics.accuracy_score(y_test, y_pred), '\n')
    
print(metAccu.__doc__)
# Out:
# Accuracy: 0.9633333333333334
#
#  Se procede a evaluar el modelo entrenado mediante las metricas empezamos evaluando el Accuray

# %%
def metPrec():
    
    ''' Se procede a imprimir la segunda evaluaciòn la cuàl es mediante la Precision'''

print("Precision:", metrics.precision_score(y_test, y_pred, average='macro'), '\n')
    
print(metPrec.__doc__)
# Out:
# Precision: 0.9137355340542591
#
#  Se procede a imprimir la segunda evaluaciòn la cuàl es mediante la Precision

# %%
def metRec():
    
    ''' Se procede a imprimir la ùltima evaluaciòn la cuàl es mediante el Recall'''

print("Recall:", metrics.recall_score(y_test, y_pred, average='macro'), '\n')
    
print(metRec.__doc__)
# Out:
# Recall: 0.8996362433862434
#
#  Se procede a imprimir la ùltima evaluaciòn la cuàl es mediante el Recall

# %% [markdown]
# # PRUNING - PROCESO DE PREPODADO AL ÁRBOL

# %% [markdown]
# El árbol de decisión completo es difícil de interpretar debido a la complejidad del resultado. La poda/acortamiento de un árbol es fundamental para facilitar la comprensión del resultado y optimizarlo. Esta optimización se puede realizar de tres maneras:
#
# criterion: opcional (predeterminado="gini") o Elegir medida de selección de atributo Define qué función se utilizará para medir la calidad de una división. Las opciones son "gini" y "entropía". La relación de Gini mide la impureza del nodo en un árbol de decisión. Se puede suponer que un nodo es puro cuando todos sus registros pertenecen a la misma clase.
#
# splitter: cadena, opcional (predeterminado="mejor") o estrategia dividida Define la estrategia utilizada para elegir la división en cada nodo. Las estrategias admitidas son "mejor" para elegir la mejor división y "aleatoria" para elegir la mejor división aleatoria.
#
# max_depth: int o Ninguno, opcional (predeterminado=Ninguno) o Profundidad máxima de un árbol Define la profundidad máxima del árbol. Si es Ninguno, el árbol será lo más largo posible, cuando todas las hojas estén puras (riesgo de sobreajuste del modelo).

# %%
def crearFunc():
    
    ''' Creamos nuevamente una función para crear el àrbol de decisiòn prepodado mediante el uso del método entropy'''

clf = DecisionTreeClassifier(criterion="entropy", max_depth=3)
clf = clf.fit(X_train,y_train)
y_pred = clf.predict(X_test)
print(crearFunc.__doc__)
# Out:
#  Creamos nuevamente una función para crear el àrbol de decisiòn prepodado mediante el uso del método entropy

# %%
def mostArbol1():

    ''' Creamos la funciòn donde se crea un objeto el cual recibe un búfer de cadenas, seguido a esto se exporta el árbol en formato DOT para crear nuestro gráfico y así guarda la imagen en formato png '''

dot_data = StringIO()
export_graphviz(clf, out_file=dot_data,  
                filled=True, rounded=True,
                special_characters=True,
                feature_names = caracteristicas,
                class_names=['0','1','2'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())  
graph.write_png('diabetes1.png')

print(mostArbol1.__doc__)
Image(graph.create_png())
# Out:
#  Creamos la funciòn donde se crea un objeto el cual recibe un búfer de cadenas, seguido a esto se exporta el árbol en formato DOT para crear nuestro gráfico y así guarda la imagen en formato png

# %%
def metAccu():
    
    ''' Se procede a evaluar el modelo entrenado mediante las metricas empezamos evaluando el Accuray'''

print("Accuracy:", metrics.accuracy_score(y_test, y_pred), '\n')
    
print(metAccu.__doc__)
# Out:
# Accuracy: 0.9533333333333334
#
#  Se procede a evaluar el modelo entrenado mediante las metricas empezamos evaluando el Accuray

# %%
def metPrec():
    
    ''' Se procede a imprimir la segunda evaluaciòn la cuàl es mediante la Precision'''

print("Precision:", metrics.precision_score(y_test, y_pred, average='macro'), '\n')
    
print(metPrec.__doc__)
# Out:
# Precision: 0.9135686274509803
#
#  Se procede a imprimir la segunda evaluaciòn la cuàl es mediante la Precision

# %%
def metRec():
    
    ''' Se procede a imprimir la ùltima evaluaciòn la cuàl es mediante el Recall'''

print("Recall:", metrics.recall_score(y_test, y_pred, average='macro'), '\n')
    
print(metRec.__doc__)
# Out:
# Recall: 0.9269179894179894
#
#  Se procede a imprimir la ùltima evaluaciòn la cuàl es mediante el Recall

# %%
def crearDF():
    
    ''' Creamos la Matriz de Confusiòn, mediante los resultados obtenidos del modelo entrenado'''
    
Matrix = confusion_matrix(y_test, y_pred)
sn.heatmap(Matrix, annot=True, fmt= 'd')
plt.show()

print(crearDF.__doc__)
# Out:
#  Creamos la Matriz de Confusiòn, mediante los resultados obtenidos del modelo entrenado
